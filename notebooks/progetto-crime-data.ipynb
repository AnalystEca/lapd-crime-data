# %% [markdown]
# #### TODO LIST - PROGETTO LAPD
# 1 - Verificare se i DataSet 'crime-2010-2019' e 'crime-2020-2024' abbiano le stesse colonne
# 2 - Se si, unire i due DataSet
#     Se no, utilizzare solamente il DataSet più recente
# 3 - Eseguire EDA
# 4 - Stabilire le domande
# 5 - Eseguire la pulizia del
